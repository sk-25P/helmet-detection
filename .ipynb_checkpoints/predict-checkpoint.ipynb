# %%
# !pip install ultralytics
import ultralytics
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot
import PIL
import cv2
from ultralytics import YOLO
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CfQyaK8OZE394ZBFg9c8")
project = rf.workspace("naluguru").project("helmet_detection-zvqkp")
dataset = project.version(1).download("yolov8")

from roboflow import Roboflow
rf = Roboflow(api_key="Zy3EgKsn46GUqKCcSiwn")
project = rf.workspace("roshan-ali-vogrc").project("model-2-swioz")
dataset = project.version(1).download("yolov8")
# Out:
# Requirement already satisfied: ultralytics in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (8.1.8)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (3.8.1)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (1.26.1)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (10.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (1.12.0)
# Requirement already satisfied: torch>=1.8.0 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (5.9.6)
# Requirement already satisfied: py-cpuinfo in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (4.8.0)
# Requirement already satisfied: sympy in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (2023.12.2)
# Requirement already satisfied: colorama in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from cycler>=0.10->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %%
model1=YOLO('best1.pt')

model2=YOLO('best2.pt')

# %%
def predictor_two_wheeler(image):
    ans=True
    img=cv2.imread(image)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img_copy=img.copy()
    result1=model1.predict(img,show_boxes=True)
    print(result1[0].boxes)
    two_wheel_box=result1[0].boxes.xywhn.tolist()
    vehicle_detect_cls=result1[0].boxes.cls.tolist()
    if vehicle_detect_cls.count(1)== 0:
        return True,img
    else:
        for cls_prob,b_box in zip(vehicle_detect_cls,two_wheel_box):
            if cls_prob == 1:
                dh,dw,_=img.shape
                lx,ly,rx,ry=b_box_cord(b_box,dh,dw)
                crop_img=img_copy[ly:ry,lx:rx]
                val,p_img=predict_without_helmet(crop_img)
                if val == False:
                    ans=False
                    #pyplot.imshow(crop_img)
                    pyplot.imshow(p_img)
                    pyplot.show()
                    
    return ans

# %%
def predict_without_helmet(image):
    ans=True
    result2=model2.predict(image,show_boxes=True)
    cls_m2=result2[0].boxes.cls.tolist()
    print(result2[0].boxes)
    bounding_boxes=result2[0].boxes.xywhn.tolist()
    if cls_m2.count(1)==0:
        return True,image
    else:
        for cls_,b_box in zip(cls_m2,bounding_boxes):
            print(cls_)
            if cls_ == 1:
                ans=False
                dh,dw,_=image.shape
                lx,ly,rx,ry=b_box_cord(b_box,dh,dw)
                print(b_box)
                cv2.rectangle(image,(lx,ly),(rx,ry),(255,0,0),3)
                #cv2.rectangle(image,(int(b_box[0]-b_box[2]/2),int(b_box[1]-b_box[3]/2)),(int((b_box[0]-b_box[2]/2)+b_box[2]),int((b_box[1]-b_box[3]/2)+b_box[3])),(255,0,0),3)
                
    return ans,image

# %%
def b_box_cord(values,dh,dw):
    
    lx=int((values[0]-values[2]/2)*dw)
    ly=int((values[1]-values[3]/2)*dh)
    rx=int((values[0]+values[2]/2)*dw)
    ry=int((values[1]+values[3]/2)*dh)
    if lx<0:
        lx=0
    if rx>dw-1:
        rx=dw-1
    if ly<0:
        ly=0
    if ry>dh-1:
        ry=dh-1
    return lx,ly,rx,ry

# %%
x=predictor_two_wheeler('datasets/Model-2--1/train/images/BikesHelmets150_png.rf.ffc7e0c977db739b28cfaced50d2c2d0.jpg')
# !pip install requests
import requests
url="         fhenf "
#if x==False:
    #request.call("  ")
# Out:
# 0: 640x640 3 two_wheelers, 1 z_null, 637.2ms
# Speed: 3.0ms preprocess, 637.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1., 1., 1., 2.])
# conf: tensor([0.8999, 0.8883, 0.8701, 0.7451])
# data: tensor([[158.5539,  69.7007, 350.5333, 567.2725,   0.8999,   1.0000],
#         [450.3240, 115.4344, 638.2859, 579.8420,   0.8883,   1.0000],
#         [334.6551, 119.3734, 469.6113, 491.6359,   0.8701,   1.0000],
#         [  0.0000, 103.1531, 176.7888, 431.6620,   0.7451,   2.0000]])
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([4, 6])
# xywh: tensor([[254.5436, 318.4866, 191.9794, 497.5718],
#         [544.3049, 347.6382, 187.9619, 464.4076],
#         [402.1332, 305.5046, 134.9562, 372.2626],
#         [ 88.3944, 267.4076, 176.7888, 328.5089]])
# xywhn: tensor([[0.3977, 0.4976, 0.3000, 0.7775],
#         [0.8505, 0.5432, 0.2937, 0.7256],
#         [0.6283, 0.4774, 0.2109, 0.5817],
#         [0.1381, 0.4178, 0.2762, 0.5133]])
# xyxy: tensor([[158.5539,  69.7007, 350.5333, 567.2725],
#         [450.3240, 115.4344, 638.2859, 579.8420],
#         [334.6551, 119.3734, 469.6113, 491.6359],
#         [  0.0000, 103.1531, 176.7888, 431.6620]])
# xyxyn: tensor([[0.2477, 0.1089, 0.5477, 0.8864],
#         [0.7036, 0.1804, 0.9973, 0.9060],
#         [0.5229, 0.1865, 0.7338, 0.7682],
#         [0.0000, 0.1612, 0.2762, 0.6745]])
#
# 0: 640x256 2 With_helmets, 283.3ms
# Speed: 1.3ms preprocess, 283.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 256)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0.])
# conf: tensor([0.8690, 0.4215])
# data: tensor([[ 72.2656,  38.4338, 120.4107, 121.6812,   0.8690,   0.0000],
#         [ 34.2880,  78.2363,  68.7769, 131.6630,   0.4215,   0.0000]])
# id: None
# is_track: False
# orig_shape: (498, 192)
# shape: torch.Size([2, 6])
# xywh: tensor([[ 96.3382,  80.0575,  48.1451,  83.2474],
#         [ 51.5324, 104.9497,  34.4889,  53.4267]])
# xywhn: tensor([[0.5018, 0.1608, 0.2508, 0.1672],
#         [0.2684, 0.2107, 0.1796, 0.1073]])
# xyxy: tensor([[ 72.2656,  38.4338, 120.4107, 121.6812],
#         [ 34.2880,  78.2363,  68.7769, 131.6630]])
# xyxyn: tensor([[0.3764, 0.0772, 0.6271, 0.2443],
#         [0.1786, 0.1571, 0.3582, 0.2644]])
#
# 0: 640x288 2 Without_helmets, 292.6ms
# Speed: 1.5ms preprocess, 292.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 288)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1., 1.])
# conf: tensor([0.8270, 0.8129])
# data: tensor([[ 34.8092,  30.1492,  70.5639,  81.8859,   0.8270,   1.0000],
#         [ 69.3761,  32.0113, 116.1201, 103.0972,   0.8129,   1.0000]])
# id: None
# is_track: False
# orig_shape: (464, 188)
# shape: torch.Size([2, 6])
# xywh: tensor([[52.6866, 56.0175, 35.7547, 51.7367],
#         [92.7481, 67.5543, 46.7440, 71.0859]])
# xywhn: tensor([[0.2802, 0.1207, 0.1902, 0.1115],
#         [0.4933, 0.1456, 0.2486, 0.1532]])
# xyxy: tensor([[ 34.8092,  30.1492,  70.5639,  81.8859],
#         [ 69.3761,  32.0113, 116.1201, 103.0972]])
# xyxyn: tensor([[0.1852, 0.0650, 0.3753, 0.1765],
#         [0.3690, 0.0690, 0.6177, 0.2222]])
# 1.0
# [0.2802477478981018, 0.12072742730379105, 0.19018447399139404, 0.11150142550468445]
# 1.0
# [0.4933411478996277, 0.1455911248922348, 0.24863843619823456, 0.1532023549079895]
# 0: 640x256 1 With_helmet, 266.0ms
# Speed: 2.4ms preprocess, 266.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 256)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8711])
# data: tensor([[ 40.2683,  39.7548,  82.9336, 115.5235,   0.8711,   0.0000]])
# id: None
# is_track: False
# orig_shape: (372, 135)
# shape: torch.Size([1, 6])
# xywh: tensor([[61.6010, 77.6392, 42.6653, 75.7687]])
# xywhn: tensor([[0.4563, 0.2087, 0.3160, 0.2037]])
# xyxy: tensor([[ 40.2683,  39.7548,  82.9336, 115.5235]])
# xyxyn: tensor([[0.2983, 0.1069, 0.6143, 0.3105]])
# Requirement already satisfied: requests in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\koush\appdata\local\programs\python\python311\lib\site-packages (from requests) (2023.7.22)

# %%
x=PIL.Image.open('datasets/Model-2--1/train/images/BikesHelmets150_png.rf.ffc7e0c977db739b28cfaced50d2c2d0.jpg')
pyplot.imshow(x)
